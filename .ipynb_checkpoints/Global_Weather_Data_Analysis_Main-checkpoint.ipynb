# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Import Modules
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
import os

#Import API Key
from api_keys import api_key

#Define Current Path & Items in Current Working Directory
current_path = os.getcwd()
current_directory = os.listdir()

#Loop Through Items in Current Working Directory
for item in current_directory:
    
    #Find Folder for Global Weather Data
    if item.lower().find('global weather data') >= 0:
        
        #Define Output File Name & Path
        output_file = current_path + '/' + item + '/Global_Weather_Data.csv'
        
    #Find Folder for Output Plots
    elif item.lower().find('images') >= 0:
        
        #Define File Path for Output Plots
        output_plot = current_path + '/' + item + '/'

#Define Range of Latitudes & Longitudes
lat_range = (-90, 90)
long_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

#Create Set of Random Latitude & Longitude Combinations
lats = np.random.uniform(low = lat_range[0], high = lat_range[1], size = 2000)
lngs = np.random.uniform(low = long_range[0], high = long_range[1], size = 2000)
lat_lngs = zip(lats, lngs)

#Loop Through Latitude & Longitude Combinations
for lat_lng in lat_lngs:
    
    #Collect Name of Nearest City for Each Latitude & Longitude Combination
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    #Check if City Name Has Already Been Found
    if city not in cities:
        
        #Append New City Names to Final List of Cities
        cities.append(city)

#Print Length of City Name List
len(cities)
# Out:
# 772

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Set Open Weather Map API Base URL
base_url = 'http://api.openweathermap.org/data/2.5/weather?q='

#Define Python Lists for Individual Weather Parameters
city = []
cloud = []
country = []
date = []
humidity = []
latitude = []
longitude = []
temp = []
wind = []

#Set Counter Variable for API Status Messages
count_1 = 1

#Print API Start Status Message
print('Starting Weather Data Collection from API.')
print('----------------------------------')

#Loop Through List of City Names
for name in cities:
    
    #Set Full API URL for Individual City
    full_url = base_url + name + '&APPID=' + api_key + '&units=imperial'
    
    #Collect Individual City Data from API
    raw_data = requests.get(full_url).json()
    
    #Print API Status Message for Individual City
    print('Processing City ' + str(count_1) + ': ' + name.title())
    
    #Set Condition for City Found In API Database
    if raw_data['cod'] == 200:
        
        #Write Individual City Data to Individual Weather Parameter Lists
        city.append(raw_data.get('name'))
        cloud.append(raw_data['clouds']['all'])
        country.append(raw_data['sys']['country'])
        date.append(raw_data['dt'])
        humidity.append(raw_data['main']['humidity'])
        latitude.append(raw_data['coord']['lat'])
        longitude.append(raw_data['coord']['lon'])
        temp.append(raw_data['main']['temp_max'])
        wind.append(raw_data['wind']['speed'])
    else:
        
        #Print API Status Message For Individual City No Found in API Databse
        print(name.title() + ' Not Found! Skipping!')
    
    #Pause Code to Prevent Exceeding API Call Limit
    time.sleep(1.5)
    
    #Increment Counter Variable for API Status Messages
    count_1 = count_1 + 1

#Print API End Status Message
print('----------------------------------')
print('Weather Data Collection Completed')
# Out:
# Starting Weather Data Collection from API.
# ----------------------------------
# Processing City 1: Bethel
# Processing City 2: Vaitupu
# Vaitupu Not Found! Skipping!
# Processing City 3: Yellowknife
# Processing City 4: Mitsamiouli
# Processing City 5: Sao Joao Da Barra
# Processing City 6: Lebu
# Processing City 7: Kodiak
# Processing City 8: Qaanaaq
# Processing City 9: Marzuq
# Processing City 10: Hilo
# Processing City 11: Taolanaro
# Taolanaro Not Found! Skipping!
# Processing City 12: Dalbandin
# Processing City 576: Pyaozerskiy
# Processing City 577: Sangar
# Processing City 578: Rurrenabaque
# Processing City 579: Livingstone
# Processing City 580: Artyom
# Processing City 581: Dharmadam
# Processing City 582: Paragominas
# Processing City 583: Pyshchug
# Processing City 584: Markova
# Processing City 585: Dalianwan
# Processing City 586: Shakiso
# Processing City 587: San Joaquin
# Processing City 588: Duluth
# Processing City 589: Port-Gentil
# Processing City 590: Bulawayo
# Processing City 591: Kadykchan
# Kadykchan Not Found! Skipping!
# Processing City 592: Poum
# Processing City 593: Trinidad
# Processing City 594: Harbour Breton
# Processing City 595: Maisuru
# Maisuru Not Found! Skipping!
# Processing City 596: Springbok
# Processing City 597: Egvekinot
# Processing City 598: Muzhi
# Processing City 599: Shishou
# Processing City 600: Sioux Lookout
# Processing City 601: Deutschlandsberg
# Processing City 602: Broome
# Processing City 603: Mach
# Processing City 604: Erzin
# Processing City 605: Byron Bay
# Processing City 606: Cururupu
# Processing City 607: Vostok
# Processing City 608: Khandyga
# Processing City 609: Paris
# Processing City 610: Mango
# Processing City 611: Muscat
# Processing City 612: Hailey
# Processing City 613: Chancay
# Processing City 614: Nogliki
# Processing City 615: Hofn
# Processing City 616: Usinsk
# Processing City 617: Orange Cove
# Processing City 618: Bonfim
# Processing City 619: Zamora
# Processing City 620: Jalu
# Processing City 621: Lixourion
# Processing City 622: Saint-Joseph
# Processing City 623: Bestobe
# Processing City 624: Shache
# Processing City 625: Turochak
# Processing City 626: Ixtapa
# Processing City 627: Saint Simons
# Processing City 628: Namatanai
# Processing City 629: Te Anau
# Processing City 630: Margherita
# Processing City 631: Kijang
# Processing City 632: Qingdao
# Processing City 633: Caledon
# Processing City 634: Belmonte
# Processing City 635: Lavumisa
# Processing City 636: Izvestkovyy
# Processing City 637: Matadi
# Processing City 638: Pankrushikha
# Processing City 639: Sao Filipe
# Processing City 640: Bontang
# Processing City 641: Tarata
# Processing City 642: Sucua
# Processing City 643: Shahrud
# Processing City 644: Pouebo
# Processing City 645: Kenora
# Processing City 646: Havoysund
# Processing City 647: Galgani
# Galgani Not Found! Skipping!
# Processing City 648: Ures
# Processing City 649: Vaitape
# Processing City 650: Umrala
# Processing City 651: Tarhunah
# Tarhunah Not Found! Skipping!
# Processing City 652: Angoram
# Processing City 653: Mareeba
# Processing City 654: Gumdag
# Processing City 655: Amapa
# Processing City 656: Quzhou
# Processing City 657: Bambanglipuro
# Processing City 658: Marystown
# Processing City 659: Lompoc
# Processing City 660: Rio Gallegos
# Processing City 661: Taoudenni
# Processing City 662: Paamiut
# Processing City 663: Maiduguri
# Processing City 664: Tyret Pervaya
# Processing City 665: Aleksandrov Gay
# Processing City 666: Oistins
# Processing City 667: Townsville
# Processing City 668: Davila
# Processing City 669: Culfa
# Processing City 670: Aripuana
# Processing City 671: Mahadday Weyne
# Mahadday Weyne Not Found! Skipping!
# Processing City 672: Ambilobe
# Processing City 673: Katherine
# Processing City 674: Kurilsk
# Processing City 675: Challapata
# Processing City 676: Makakilo City
# Processing City 677: Pimampiro
# Processing City 678: Kotka
# Processing City 679: Jaumave
# Processing City 680: Mogadishu
# Processing City 681: Constitucion
# Processing City 682: Kerema
# Processing City 683: Villa Guerrero
# Processing City 684: Evensk
# Processing City 685: Buala
# Processing City 686: Wittenberge
# Processing City 687: Roros
# Processing City 688: Vila Velha
# Processing City 689: Hambantota
# Processing City 690: Tidore
# Tidore Not Found! Skipping!
# Processing City 691: Beberibe
# Processing City 692: Newton
# Processing City 693: Urucara
# Processing City 694: Mako
# Processing City 695: Aflu
# Aflu Not Found! Skipping!
# Processing City 696: Koungou
# Koungou Not Found! Skipping!
# Processing City 697: Wilmington
# Processing City 698: Kuzhener
# Processing City 699: Barabinsk
# Processing City 700: Klyuchi
# Processing City 701: Dhenkanal
# Processing City 702: Zhuravky
# Processing City 703: Aksarka
# Processing City 704: Varnamo
# Processing City 705: Athens
# Processing City 706: Tual
# Processing City 707: Talnakh
# Processing City 708: Nizwa
# Processing City 709: Tostamaa
# Tostamaa Not Found! Skipping!
# Processing City 710: Preeceville
# Processing City 711: El Chimbo
# Processing City 712: Anori
# Processing City 713: Puntarenas
# Processing City 714: Miyako
# Processing City 715: Narasannapeta
# Processing City 716: Lithakia
# Processing City 717: Piranshahr
# Processing City 718: Sillamae
# Processing City 719: Zhongshu
# Processing City 720: Valky
# Processing City 721: Austin
# Processing City 722: Vanavara
# Processing City 723: Dubbo
# Processing City 724: Esik
# Processing City 725: Kailua
# Processing City 726: Richards Bay
# Processing City 727: Nsanje
# Processing City 728: Mastic Beach
# Processing City 729: Mossendjo
# Processing City 730: Sal Rei
# Processing City 731: Tchamba
# Processing City 732: Rolim De Moura
# Rolim De Moura Not Found! Skipping!
# Processing City 733: Cap Malheureux
# Processing City 734: Zaozerne
# Processing City 735: Toftir
# Toftir Not Found! Skipping!
# Processing City 736: Loa Janan
# Processing City 737: Devonport
# Processing City 738: Zinder
# Processing City 739: Jasper
# Processing City 740: Sekoma
# Processing City 741: Santa Rosa
# Processing City 742: Mujiayingzi
# Processing City 743: Manchester
# Processing City 744: Stromness
# Processing City 745: Bonanza
# Processing City 746: Zilina
# Processing City 747: Chilon
# Processing City 748: Bonthe
# Processing City 749: Prince Albert
# Processing City 750: Verkh-Chebula
# Processing City 751: Norfolk
# Processing City 752: Vila Franca Do Campo
# Processing City 753: Ruatoria
# Ruatoria Not Found! Skipping!
# Processing City 754: Merauke
# Processing City 755: Impfondo
# Processing City 756: Chapais
# Processing City 757: Xingcheng
# Processing City 758: Moelv
# Processing City 759: Bargal
# Bargal Not Found! Skipping!
# Processing City 760: Eyl
# Processing City 761: Ilulissat
# Processing City 762: Los Llanos De Aridane
# Processing City 763: Sisimiut
# Processing City 764: Broken Hill
# Processing City 765: Ryotsu
# Processing City 766: Nazarovo
# Processing City 767: Sibolga
# Processing City 768: Sterling
# Processing City 769: Krasnaya Gorka
# Processing City 770: Itzehoe
# Processing City 771: Nacala
# Processing City 772: Simao
# ----------------------------------
# Weather Data Collection Completed

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create Data Frame of Combined City Weather
city_data = pd.DataFrame({'City': city, 'Cloudiness (%)': cloud, 'Country': country, 'Date': date, 'Humidity (%)': humidity,
                          'Latitude': latitude, 'Longitude': longitude, 'Max Temp (F)': temp, 'Wind Speed (mph)': wind})

#Display Combined City Weather Data Frame
city_data
# Out:
#                       City  Cloudiness (%) Country        Date  Humidity (%)  \
# 0                   Bethel              40      US  1571699748            86
# 1              Yellowknife              90      CA  1571699975            79
# 2              Mitsamiouli              20      KM  1571700160            83
# 3        Sao Joao da Barra             100      BR  1571700162            75
# 4                     Lebu              40      ET  1571699767            71
# 5                   Kodiak              90      US  1571699783            62
# 6                  Qaanaaq               0      GL  1571700167            38
# 7                   Marzuq               0      YE  1571700169            56
# 8                     Hilo              75      US  1571699607            66
# 9                Dalbandin              11      PK  1571700174            18
# 10                   Alofi              75      NU  1571700176            83
# 11          Port Elizabeth              75      US  1571699605            77
# 12                  Albany              20      US  1571700180            76
# 13                 Ushuaia              40      AR  1571700182            40
# 14                   Kapaa              75      US  1571700183            78
# 15                  Laguna              40      BZ  1571700185            74
# 16               Coihaique              20      CL  1571699998            57
# 17          Saint-Philippe               1      CA  1571699683            76
# 18            Mizan Teferi              82      ET  1571699805            96
# 19                   Bluff               3      AU  1571700194            41
# 20               Cape Town               0      ZA  1571699625            64
# 21                  Madang              50      CN  1571700197            72
# 22                 Ahipara               7      NZ  1571699881            85
# 23               Busselton              18      AU  1571700201            64
# 24          Ribeira Grande              64      PT  1571699768            75
# 25              Codrington              25      AU  1571700206            49
# 26                   Vaini             100      IN  1571700208            96
# 27               Mahebourg              40      MU  1571699729            88
# 28                  Atuona               6      PF  1571700212            76
# 29         Arraial do Cabo              75      BR  1571700214            64
# ..                     ...             ...     ...         ...           ...
# 672             Santa Rosa               0      AR  1571701588            25
# 673            Mujiayingzi               0      CN  1571701590            31
# 674             Manchester               1      US  1571701592            76
# 675              Stromness              90      CA  1571701593            93
# 676                Bonanza              74      NI  1571701595            98
# 677                 Zilina              16      SK  1571701597            93
# 678                 Chilon              97      BO  1571701600            87
# 679                 Bonthe             100      SL  1571701601            89
# 680          Prince Albert              75      CA  1571701603            52
# 681          Verkh-Chebula              89      RU  1571701605            76
# 682                Norfolk              90      US  1571701607            93
# 683   Vila Franca do Campo              20      PT  1571701609            77
# 684                Merauke              62      ID  1571701613            50
# 685               Impfondo              99      CD  1571701614            94
# 686                Chapais              20      CA  1571701617            81
# 687              Xingcheng              16      CN  1571701619            27
# 688                  Moelv             100      NO  1571701621            97
# 689                    Eyl               0      SO  1571701624            79
# 690              Ilulissat               7      GL  1571701626            41
# 691  Los Llanos de Aridane              40      ES  1571701628            59
# 692               Sisimiut              46      GL  1571701630            57
# 693            Broken Hill              85      AU  1571701631            25
# 694                 Ryotsu              75      JP  1571701633            88
# 695               Nazarovo              95      RU  1571701635            79
# 696                Sibolga              79      ID  1571701637            94
# 697               Sterling               1      US  1571701639            72
# 698         Krasnaya Gorka             100      RU  1571701641            81
# 699                Itzehoe              48      DE  1571701643            87
# 700                 Nacala               0      MZ  1571701645            90
# 701                  Simao              65      CN  1571701647            97
#
#      Latitude  Longitude  Max Temp (F)  Wind Speed (mph)
# 0       60.79    -161.76         39.20             10.29
# 1       62.45    -114.38         28.40             11.41
# 2      -11.38      43.28         75.20              5.82
# 3      -21.64     -41.05         69.89              5.48
# 4        8.96      38.73         55.40              2.24
# 5       39.95     -94.76         54.00             17.22
# 6       77.48     -69.36          5.29             10.89
# 7       14.40      46.47         65.75              2.26
# 8       19.71    -155.08         84.20              6.93
# 9       28.90      64.41         66.33              3.47
# 10     -19.06    -169.92         80.60              3.36
# 11      39.31     -74.98         62.60              6.35
# 12      42.65     -73.75         54.00              4.63
# 13     -54.81     -68.31         51.80             16.11
# 14      22.08    -159.32         84.20              9.17
# 15      16.17     -88.94         86.00              4.70
# 16     -45.58     -72.07         48.20              3.36
# 17      45.36     -73.48         55.40              4.70
# 18       6.99      35.58         60.75              3.44
# 19     -23.58     149.07         75.56             15.19
# 20     -33.93      18.42         55.99              7.00
# 21      35.32     102.79         41.59              2.44
# 22     -35.17     173.16         70.00             18.66
# 23     -33.64     115.35         64.99              3.00
# 24      38.52     -28.70         62.60              8.21
# 25     -28.95     153.24         71.60              5.82
# 26      15.34      74.49         68.00              1.97
# 27     -20.41      57.70         73.99             10.29
# 28      -9.80    -139.03         79.39             14.47
# 29     -22.97     -42.02         71.60              2.24
# ..        ...        ...           ...               ...
# 672    -36.62     -64.29         54.91              9.10
# 673     42.12     118.78         48.00              3.56
# 674     43.00     -71.45         53.01              5.82
# 675     42.87     -79.55         64.00             16.11
# 676     14.03     -84.62         73.65              0.27
# 677     49.22      18.74         57.99              3.36
# 678    -18.00     -64.64         59.25              4.79
# 679      7.53     -12.50         78.31              4.65
# 680     53.20    -105.75         42.80              5.82
# 681     56.03      87.61         21.87             14.74
# 682     36.85     -76.29         61.00              4.45
# 683     37.72     -25.43         60.80              4.70
# 684     -8.49     140.40         87.10              8.41
# 685      1.62      18.06         71.42              0.85
# 686     49.78     -74.86         42.80              3.65
# 687     40.62     120.71         53.92              3.00
# 688     60.93      10.70         37.99              3.91
# 689      7.98      49.82         80.47             12.01
# 690     69.22     -51.10         19.40              3.36
# 691     28.66     -17.92         66.20             10.29
# 692     66.94     -53.67         21.07             10.56
# 693    -31.97     141.45         73.40             13.87
# 694     38.08     138.43         62.60              4.70
# 695     56.01      90.42         20.03              6.98
# 696      1.74      98.78         72.28              1.72
# 697     39.00     -77.40         62.01              3.36
# 698     55.19      56.67         41.72             19.60
# 699     53.92       9.52         52.00              4.70
# 700    -14.56      40.69         73.62              5.21
# 701     22.76     100.79         60.13              3.02
#
# [702 rows x 9 columns]

# %%
#Export Combined City Weather Data Frame to CSV File
city_data.to_csv(output_file, index = False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Plot Latitude Data Versus Maximum Temperature Data
F1, AX1 = plt.subplots()
AX1.scatter(city_data['Latitude'], city_data['Max Temp (F)'], facecolor = 'blue', edgecolor = 'black')
AX1.grid()
AX1.set_title('Maximum Temperature vs City Latitude')
AX1.set_xlabel('City Latitude')
AX1.set_ylabel('Max Temp (F)')
plt.savefig(output_plot + 'Maximum_Temperature_vs_City_Latitude.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Plot Latitude Data Versus Humidity Data
F2, AX2 = plt.subplots()
AX2.scatter(city_data['Latitude'], city_data['Humidity (%)'], facecolor = 'blue', edgecolor = 'black')
AX2.grid()
AX2.set_title('Humidity vs City Latitude')
AX2.set_xlabel('City Latitude')
AX2.set_ylabel('Humidity (%)')
plt.savefig(output_plot + 'Humidity_vs_City_Latitude.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Plot Latitude Data Versus Cloudiness Data
F3, AX3 = plt.subplots()
AX3.scatter(city_data['Latitude'], city_data['Cloudiness (%)'], facecolor = 'blue', edgecolor = 'black')
AX3.grid()
AX3.set_title('Cloudiness vs City Latitude')
AX3.set_xlabel('City Latitude')
AX3.set_ylabel('Cloudiness (%)')
plt.savefig(output_plot + 'Cloudiness_vs_City_Latitude.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Plot Latitude Data Versus Wind Speed Data
F4, AX4 = plt.subplots()
AX4.scatter(city_data['Latitude'], city_data['Wind Speed (mph)'], facecolor = 'blue', edgecolor = 'black')
AX4.grid()
AX4.set_title('Wind Speed vs City Latitude')
AX4.set_xlabel('City Latitude')
AX4.set_ylabel('Wind Speed (mph)')
plt.savefig(output_plot + 'Wind_Speed_vs_City_Latitude.png')
plt.show()

# %% [markdown]
# ## Observations

# %% [markdown]
# The purpose of this assignment was to analyze current weather data from over 500 randomly selected global cities. The Numpy, Citipy, and Requests modules in Python were used to generate random latitude and longitude combinations, find the name of the nearest city for each combination, and extract weather data from the Open Weather Map API for each city. Python's Pandas and Matplotlib modules were used to process this data to find certain metrics and generate plots to display meaningful results. This facilitated several observations regarding how maximum temperature, humidity, wind speed, and cloudiness vary based on a city's latitude.
#
# Examining the maximum temperature data, there is a clear trend showing a drop in temperature the farther a city is located from the equatorial region. The scatter plot is flat between the latitudes of -20 and 20, but then drops off roughly evenly in both directions until the latitudes of -60 and 60. Beyond that point, it can be assumed that this trend continues to both polar regions, but there is not sufficient data approaching the Antarctic region of the southern hemisphere. This trend is explained by the curvature and tilt of the Earth. The equatorial regions are at the widest part of the planet and aren't as affected by Earth's curvature and tilt relative to the sun. Therefore, they receive more consistent sunlight all year long, which results in higher maximum temperatures. In contrast, cities farther to the north or south receive less sunlight due to the curvature and tilt, which results in lower maximum temperatures.
#
# In regard to the humidity and wind speed data, it is evident that the majority of cities have humidity percentages above 60 percent and wind speeds below 15 miles per hour. In both cases, the scatter plots show the data primarily grouped in those zones, regardless of latitude. Humidity percentages are more likely tied to the climactic region of a particular city and specific weather patterns in that area. Wind speeds could be tied to a city's altitude, surrounding geographical/physical features, and/or current weather systems.
#
# Reviewing the cloudiness data, there is no clear correlation present with respect to latitude. The scatter plot shows a near even distibution of data throughout, although there are some small groupings present. Cloudiness is more dependent on a city's daily weather. For example, a rainy or snowy day would more likely have a higher cloud percentage, while a sunny day would generally have a lower percentage.
